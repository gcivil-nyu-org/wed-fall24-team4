# %%
pip install sodapy

# %%
#!/usr/bin/env python

# make sure to install these packages before running:
# pip install pandas
# pip install sodapy

import pandas as pd
from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.ny.gov", None)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.ny.gov,
#                  MyAppToken,
#                  username="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("39hk-dx4f", limit=2000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
results_df
# Out:
#     gtfs_stop_id station_id complex_id division        line  \
# 0            R01          1          1      BMT     Astoria
# 1            R03          2          2      BMT     Astoria
# 2            R04          3          3      BMT     Astoria
# 3            R05          4          4      BMT     Astoria
# 4            R06          5          5      BMT     Astoria
# ..           ...        ...        ...      ...         ...
# 195          A65        195        195      IND  Liberty Av
# 196          H01        196        196      IND    Rockaway
# 197          H02        197        197      IND    Rockaway
# 198          H03        198        198      IND    Rockaway
# 199          H04        199        199      IND    Rockaway
#
#                     stop_name borough    cbd daytime_routes structure  ...  \
# 0        Astoria-Ditmars Blvd       Q  FALSE            N W  Elevated  ...
# 1                Astoria Blvd       Q  FALSE            N W  Elevated  ...
# ...

# %%
results_df.to_json('data.json', orient='records', lines=True)

print("Data saved to data.json")
# Out:
# Data saved to data.json

# %%
results2 = client.get("rc78-7x78", limit=20)

# Convert to pandas DataFrame
results_df2 = pd.DataFrame.from_records(results)

results_df2.to_json('data.json2', orient='records', lines=True)

print("Data saved to data.json2")
# Out:
# Data saved to data.json2
